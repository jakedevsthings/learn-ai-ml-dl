# %% [markdown]
# # XOR Neural Network Visualization
#
# This notebook demonstrates training a neural network on the XOR problem and visualizing the decision boundary.

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('..')

from ml_core_numpy.losses import BinaryCrossentropy as BCE_Loss
from ml_core_numpy import Network as Neural_Network
from ml_core_numpy.layers import DenseLayer as Dense_Layer
from ml_core_numpy.activations import Sigmoid as Sigmoid_Activation
from ml_core_numpy.activations import ReLU as ReLU_Activation
from ml_core_numpy.activations import Tanh as Tanh_Activation

# %% [markdown]
# ## XOR Dataset
#
# The XOR (exclusive OR) problem is a classic non-linear classification problem that cannot be solved by a single-layer perceptron.

# %%
# Define XOR inputs and expected outputs
inputs = [
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
]
labels = [
    [0],
    [1],
    [1],
    [0]
]

# Convert labels to numpy array for calculations
labels = np.array(labels)

# %% [markdown]
# ## Training the Neural Network
#
# We'll create a neural network with:
# - 2 input neurons (for the 2 XOR inputs)
# - 4 neurons in the hidden layer
# - 1 output neuron (for binary classification)

# %%
# Training parameters
num_epochs = 5000
learning_rate = 0.2

# Initialize the loss function
bce_loss = BCE_Loss()

# Initialize the network
# 2 inputs, 4 hidden, 1 output
neural_network = Neural_Network([
    Dense_Layer(input_size=2, output_size=4, initializer='xavier'),
    Tanh_Activation(),
    Dense_Layer(input_size=4, output_size=1, initializer='xavier'),
    Sigmoid_Activation(),
])

# Lists to track progress
loss_history = []
accuracy_history = []

for epoch in range(num_epochs):
    # Forward pass
    predictions = neural_network.forward(inputs=inputs)
    loss = bce_loss.forward(predictions=predictions, labels=labels)
    gradient = bce_loss.backward()
    
    # Backward pass
    neural_network.backward(loss_gradient=gradient, learning_rate=learning_rate)
    
    # Record loss every so often
    if epoch % 10 == 0 or epoch == num_epochs - 1:
        loss_history.append(loss)
        predicted_labels = (predictions > 0.5).astype(int)
        accuracy = (predicted_labels == labels).sum() / len(labels)
        accuracy_history.append(accuracy)
        if epoch % 100 == 0 or epoch == num_epochs - 1:
            print(f"Epoch {epoch}/{num_epochs}, Loss: {loss:.6f}, Accuracy: {accuracy * 100:.2f}%")

final_predictions = neural_network.forward(inputs=inputs)
final_preds_rounded = (final_predictions > 0.5).astype(int)
final_accuracy = (final_preds_rounded == labels).sum() / len(labels)

print(f"\nFinal XOR Accuracy: {final_accuracy * 100:.2f}% ✅")
# Out:
# Epoch 0/5000, Loss: 0.815150, Accuracy: 50.00%
# Epoch 100/5000, Loss: 0.712516, Accuracy: 75.00%
# Epoch 200/5000, Loss: 0.695407, Accuracy: 75.00%
# Epoch 300/5000, Loss: 0.689873, Accuracy: 75.00%
# Epoch 400/5000, Loss: 0.686400, Accuracy: 75.00%
# Epoch 500/5000, Loss: 0.683008, Accuracy: 75.00%
# Epoch 600/5000, Loss: 0.679194, Accuracy: 75.00%
# Epoch 700/5000, Loss: 0.674785, Accuracy: 75.00%
# Epoch 800/5000, Loss: 0.669656, Accuracy: 75.00%
# Epoch 900/5000, Loss: 0.663650, Accuracy: 75.00%
# Epoch 1000/5000, Loss: 0.656522, Accuracy: 75.00%
# Epoch 1100/5000, Loss: 0.647842, Accuracy: 75.00%
# Epoch 1200/5000, Loss: 0.636721, Accuracy: 75.00%
# Epoch 1300/5000, Loss: 0.621292, Accuracy: 75.00%
# Epoch 1400/5000, Loss: 0.598297, Accuracy: 75.00%
# Epoch 1500/5000, Loss: 0.564039, Accuracy: 75.00%
# Epoch 1600/5000, Loss: 0.516932, Accuracy: 100.00%
# Epoch 1700/5000, Loss: 0.459581, Accuracy: 100.00%
# Epoch 1800/5000, Loss: 0.397939, Accuracy: 100.00%
# Epoch 1900/5000, Loss: 0.338284, Accuracy: 100.00%
# Epoch 2000/5000, Loss: 0.284976, Accuracy: 100.00%
# Epoch 2100/5000, Loss: 0.239932, Accuracy: 100.00%
# Epoch 2200/5000, Loss: 0.203134, Accuracy: 100.00%
# Epoch 2300/5000, Loss: 0.173544, Accuracy: 100.00%
# Epoch 2400/5000, Loss: 0.149829, Accuracy: 100.00%
# Epoch 2500/5000, Loss: 0.130747, Accuracy: 100.00%
# Epoch 2600/5000, Loss: 0.115268, Accuracy: 100.00%
# Epoch 2700/5000, Loss: 0.102588, Accuracy: 100.00%
# Epoch 2800/5000, Loss: 0.092090, Accuracy: 100.00%
# Epoch 2900/5000, Loss: 0.083308, Accuracy: 100.00%
# Epoch 3000/5000, Loss: 0.075886, Accuracy: 100.00%
# Epoch 3100/5000, Loss: 0.069555, Accuracy: 100.00%
# Epoch 3200/5000, Loss: 0.064106, Accuracy: 100.00%
# Epoch 3300/5000, Loss: 0.059379, Accuracy: 100.00%
# Epoch 3400/5000, Loss: 0.055247, Accuracy: 100.00%
# Epoch 3500/5000, Loss: 0.051611, Accuracy: 100.00%
# Epoch 3600/5000, Loss: 0.048391, Accuracy: 100.00%
# Epoch 3700/5000, Loss: 0.045522, Accuracy: 100.00%
# Epoch 3800/5000, Loss: 0.042953, Accuracy: 100.00%
# Epoch 3900/5000, Loss: 0.040641, Accuracy: 100.00%
# Epoch 4000/5000, Loss: 0.038551, Accuracy: 100.00%
# Epoch 4100/5000, Loss: 0.036654, Accuracy: 100.00%
# Epoch 4200/5000, Loss: 0.034924, Accuracy: 100.00%
# Epoch 4300/5000, Loss: 0.033343, Accuracy: 100.00%
# Epoch 4400/5000, Loss: 0.031891, Accuracy: 100.00%
# Epoch 4500/5000, Loss: 0.030555, Accuracy: 100.00%
# Epoch 4600/5000, Loss: 0.029321, Accuracy: 100.00%
# Epoch 4700/5000, Loss: 0.028179, Accuracy: 100.00%
# Epoch 4800/5000, Loss: 0.027118, Accuracy: 100.00%
# Epoch 4900/5000, Loss: 0.026131, Accuracy: 100.00%
# Epoch 4999/5000, Loss: 0.025220, Accuracy: 100.00%
#
# Final XOR Accuracy: 100.00% ✅

# %% [markdown]
# ## Visualizing Training Progress

# %%
# Plot loss over time
plt.figure(figsize=(5, 4))
epochs_tracked = [i*num_epochs for i in range(len(loss_history)-1)] + [num_epochs-1]
plt.plot(epochs_tracked, loss_history, 'b-')
plt.title('Training Loss Over Time', fontsize=16)
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Decision Boundary Visualization

# %%
# Make predictions
final_predictions = neural_network.forward(inputs)
rounded_predictions = np.round(final_predictions)

# Display predictions vs actual
for i in range(len(inputs)):
    print(f"Input: {inputs[i]} | Actual: {labels[i][0]} | Predicted: {final_predictions[i][0]:.4f} | Rounded: {rounded_predictions[i][0]}")

# Visualize the decision boundary
from visualize import plot_decision_boundary
from visualize import plot_all_layer_activations
from visualize import plot_layer_weights

plot_decision_boundary(model=neural_network, X=inputs, y=labels, title="XOR Problem Decision Boundary")
plot_all_layer_activations(model=neural_network)
plot_layer_weights(neural_network)
# Out:
# Input: [0, 0] | Actual: 0 | Predicted: 0.0217 | Rounded: 0.0
# Input: [0, 1] | Actual: 1 | Predicted: 0.9731 | Rounded: 1.0
# Input: [1, 0] | Actual: 1 | Predicted: 0.9713 | Rounded: 1.0
# Input: [1, 1] | Actual: 0 | Predicted: 0.0223 | Rounded: 0.0
# Layer 1 Neuron 1 weights: [-2.3486382  -2.22896115  0.92629326  1.03649643]
# Layer 1 Neuron 2 weights: [ 2.47100535  2.1369463   0.65479563 -1.02419888]
# Layer 3 Neuron 1 weights: [-5.34017152]
# Layer 3 Neuron 2 weights: [4.82722159]
# Layer 3 Neuron 3 weights: [1.81855467]
# Layer 3 Neuron 4 weights: [-0.94390868]
