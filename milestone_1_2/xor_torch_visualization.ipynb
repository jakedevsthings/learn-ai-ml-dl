# %%
from ml_core_torch.models.xor_net import XORNet
from ml_core_torch.train.train_loop import train_model
from ml_core_torch.utils.data import generate_xor_dataset
from ml_core_torch.config.defaults import DEVICE, DEFAULTS
from ml_core_torch.utils.plot import plot_loss_and_accuracy

import torch
import matplotlib.pyplot as plt

# prepare data
X, y = generate_xor_dataset()

# initialize model
model = XORNet()
optimizer = torch.optim.SGD(model.parameters(), lr=DEFAULTS["lr"])
loss_fn = torch.nn.BCELoss()

# train model
losses, accuracies = train_model(
    model=model,
    inputs=X,
    labels=y,
    optimizer=optimizer,
    loss_fn=loss_fn,
    device=DEVICE,
    num_epochs=DEFAULTS["epochs"]
)

print("\n✅ Training complete.")

plot_loss_and_accuracy(losses, accuracies)
# Out:
# Epoch 0/5000, Loss: 0.7018, Accuracy: 0.5000
# Epoch 100/5000, Loss: 0.6453, Accuracy: 0.7500
# Epoch 200/5000, Loss: 0.3900, Accuracy: 1.0000
# Epoch 300/5000, Loss: 0.1490, Accuracy: 1.0000
# Epoch 400/5000, Loss: 0.0769, Accuracy: 1.0000
# Epoch 500/5000, Loss: 0.0496, Accuracy: 1.0000
# Epoch 600/5000, Loss: 0.0361, Accuracy: 1.0000
# Epoch 700/5000, Loss: 0.0281, Accuracy: 1.0000
# Epoch 800/5000, Loss: 0.0230, Accuracy: 1.0000
# Epoch 900/5000, Loss: 0.0193, Accuracy: 1.0000
# Epoch 1000/5000, Loss: 0.0167, Accuracy: 1.0000
# Epoch 1100/5000, Loss: 0.0147, Accuracy: 1.0000
# Epoch 1200/5000, Loss: 0.0131, Accuracy: 1.0000
# Epoch 1300/5000, Loss: 0.0118, Accuracy: 1.0000
# Epoch 1400/5000, Loss: 0.0107, Accuracy: 1.0000
# Epoch 1500/5000, Loss: 0.0098, Accuracy: 1.0000
# Epoch 1600/5000, Loss: 0.0091, Accuracy: 1.0000
# Epoch 1700/5000, Loss: 0.0084, Accuracy: 1.0000
# Epoch 1800/5000, Loss: 0.0078, Accuracy: 1.0000
# Epoch 1900/5000, Loss: 0.0073, Accuracy: 1.0000
# Epoch 2000/5000, Loss: 0.0069, Accuracy: 1.0000
# Epoch 2100/5000, Loss: 0.0065, Accuracy: 1.0000
# Epoch 2200/5000, Loss: 0.0062, Accuracy: 1.0000
# Epoch 2300/5000, Loss: 0.0059, Accuracy: 1.0000
# Epoch 2400/5000, Loss: 0.0056, Accuracy: 1.0000
# Epoch 2500/5000, Loss: 0.0053, Accuracy: 1.0000
# Epoch 2600/5000, Loss: 0.0051, Accuracy: 1.0000
# Epoch 2700/5000, Loss: 0.0049, Accuracy: 1.0000
# Epoch 2800/5000, Loss: 0.0047, Accuracy: 1.0000
# Epoch 2900/5000, Loss: 0.0045, Accuracy: 1.0000
# Epoch 3000/5000, Loss: 0.0043, Accuracy: 1.0000
# Epoch 3100/5000, Loss: 0.0042, Accuracy: 1.0000
# Epoch 3200/5000, Loss: 0.0040, Accuracy: 1.0000
# Epoch 3300/5000, Loss: 0.0039, Accuracy: 1.0000
# Epoch 3400/5000, Loss: 0.0038, Accuracy: 1.0000
# Epoch 3500/5000, Loss: 0.0036, Accuracy: 1.0000
# Epoch 3600/5000, Loss: 0.0035, Accuracy: 1.0000
# Epoch 3700/5000, Loss: 0.0034, Accuracy: 1.0000
# Epoch 3800/5000, Loss: 0.0033, Accuracy: 1.0000
# Epoch 3900/5000, Loss: 0.0032, Accuracy: 1.0000
# Epoch 4000/5000, Loss: 0.0031, Accuracy: 1.0000
# Epoch 4100/5000, Loss: 0.0030, Accuracy: 1.0000
# Epoch 4200/5000, Loss: 0.0030, Accuracy: 1.0000
# Epoch 4300/5000, Loss: 0.0029, Accuracy: 1.0000
# Epoch 4400/5000, Loss: 0.0028, Accuracy: 1.0000
# Epoch 4500/5000, Loss: 0.0028, Accuracy: 1.0000
# Epoch 4600/5000, Loss: 0.0027, Accuracy: 1.0000
# Epoch 4700/5000, Loss: 0.0026, Accuracy: 1.0000
# Epoch 4800/5000, Loss: 0.0026, Accuracy: 1.0000
# Epoch 4900/5000, Loss: 0.0025, Accuracy: 1.0000
# Epoch 4999/5000, Loss: 0.0025, Accuracy: 1.0000
#
# ✅ Training complete.
