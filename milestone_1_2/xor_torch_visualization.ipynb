# %%
from ml_core_torch.models.xor_net import XORNet
from ml_core_torch.train.train_loop import train_model
from ml_core_torch.utils.data import generate_xor_dataset
from ml_core_torch.config.defaults import DEVICE, DEFAULTS
from ml_core_torch.utils.plot import plot_loss_and_accuracy

import torch

# prepare data
X, y = generate_xor_dataset()

# initialize model
model = XORNet()
# stochastic gradient descent
optimizer = torch.optim.SGD(model.parameters(), lr=DEFAULTS["learning_rate"])
loss_fn = torch.nn.BCELoss()

# train model
losses, accuracies = train_model(
    model=model,
    inputs=X,
    labels=y,
    optimizer=optimizer,
    loss_fn=loss_fn,
    device=DEVICE,
    num_epochs=DEFAULTS["epochs"],
)

print("\n✅ Training complete.")

plot_loss_and_accuracy(losses, accuracies)
# Out:
# Epoch 0/5000, Loss: 0.7446, Accuracy: 0.5000
# Epoch 500/5000, Loss: 0.1080, Accuracy: 1.0000
# Epoch 1000/5000, Loss: 0.0210, Accuracy: 1.0000
# Epoch 1500/5000, Loss: 0.0112, Accuracy: 1.0000
# Epoch 2000/5000, Loss: 0.0076, Accuracy: 1.0000
# Epoch 2500/5000, Loss: 0.0057, Accuracy: 1.0000
# Epoch 3000/5000, Loss: 0.0046, Accuracy: 1.0000
# Epoch 3500/5000, Loss: 0.0038, Accuracy: 1.0000
# Epoch 4000/5000, Loss: 0.0033, Accuracy: 1.0000
# Epoch 4500/5000, Loss: 0.0029, Accuracy: 1.0000
# Epoch 4999/5000, Loss: 0.0025, Accuracy: 1.0000
#
# ✅ Training complete.
