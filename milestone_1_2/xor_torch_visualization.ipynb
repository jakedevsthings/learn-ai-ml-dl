# %%
from ml_core_torch.models.xor_net import XORNet
from ml_core_torch.train.train_loop import train_model
from ml_core_torch.utils.data import generate_xor_dataset
from ml_core_torch.config.defaults import DEVICE, DEFAULTS

import torch
import matplotlib.pyplot as plt

# prepare data
X, y = generate_xor_dataset()

# initialize model
model = XORNet()
optimizer = torch.optim.SGD(model.parameters(), lr=DEFAULTS["lr"])
loss_fn = torch.nn.BCELoss()

# train model
losses, accuracies = train_model(
    model=model,
    inputs=X,
    labels=y,
    optimizer=optimizer,
    loss_fn=loss_fn,
    device=DEVICE,
    num_epochs=DEFAULTS["epochs"]
)

print("\n✅ Training complete.")

epochs = list(range(0, len(losses)*10, 10))

# Plotting
plt.figure(figsize=(12, 5))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(epochs, losses, label='Loss', color='blue')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.grid(True)

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(epochs, accuracies, label='Accuracy', color='green')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy')
plt.ylim([0, 1.05])
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Epoch 0/5000, Loss: 0.6908, Accuracy: 0.5000
# Epoch 100/5000, Loss: 0.6225, Accuracy: 0.7500
# Epoch 200/5000, Loss: 0.4379, Accuracy: 1.0000
# Epoch 300/5000, Loss: 0.2178, Accuracy: 1.0000
# Epoch 400/5000, Loss: 0.1089, Accuracy: 1.0000
# Epoch 500/5000, Loss: 0.0659, Accuracy: 1.0000
# Epoch 600/5000, Loss: 0.0454, Accuracy: 1.0000
# Epoch 700/5000, Loss: 0.0338, Accuracy: 1.0000
# Epoch 800/5000, Loss: 0.0266, Accuracy: 1.0000
# Epoch 900/5000, Loss: 0.0217, Accuracy: 1.0000
# Epoch 1000/5000, Loss: 0.0181, Accuracy: 1.0000
# Epoch 1100/5000, Loss: 0.0155, Accuracy: 1.0000
# Epoch 1200/5000, Loss: 0.0135, Accuracy: 1.0000
# Epoch 1300/5000, Loss: 0.0119, Accuracy: 1.0000
# Epoch 1400/5000, Loss: 0.0106, Accuracy: 1.0000
# Epoch 1500/5000, Loss: 0.0095, Accuracy: 1.0000
# Epoch 1600/5000, Loss: 0.0087, Accuracy: 1.0000
# Epoch 1700/5000, Loss: 0.0079, Accuracy: 1.0000
# Epoch 1800/5000, Loss: 0.0073, Accuracy: 1.0000
# Epoch 1900/5000, Loss: 0.0067, Accuracy: 1.0000
# ...
